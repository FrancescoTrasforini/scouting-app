# %%
import pandas as pd

# %%
# Load the Excel file
file_path = "RWB search.xlsx"  # Update with your actual file path
df = pd.read_excel(file_path)

# %%
from IPython.display import display

# Display the DataFrame with all columns
display(df.head())
# Out:
#           Player                Team Team within selected timeframe  \
# 0  T. Owen-Evans     Chippenham Town                Chippenham Town
# 1       D. Sesay  Eastbourne Borough             Eastbourne Borough
# 2       T. Clark         Farnborough                    Farnborough
# 3      B. Roscoe        Radcliffe FC                   Radcliffe FC
# 4     G. Horbury             Chorley                        Chorley
#
#          Position   Age  Market value Contract expires  Matches played  \
# 0      RW, LW, CF  27.0             0              NaN              17
# 1     RB, LWB, LB  26.0             0       2025-06-30              17
# 2  RB, LDMF, RDMF  19.0             0              NaN              17
# 3         RCB, RB  27.0             0              NaN              17
# 4  RW, RCMF, LCMF  20.0             0              NaN              17
#
#    Minutes played  Goals  ...  Prevented goals per 90  \
# 0             951      4  ...                     NaN
# 1            1512      0  ...                     NaN
# 2            1580      2  ...                     NaN
# 3            1657      5  ...                     NaN
# 4            1522      1  ...                     NaN
#
#    Back passes received as GK per 90  Exits per 90  Aerial duels per 90.1  \
# 0                               0.38           NaN                    NaN
# 1                               0.60           NaN                    NaN
# 2                               1.14           NaN                    NaN
# 3                               1.85           NaN                    NaN
# 4                               0.06           NaN                    NaN
#
#    Free kicks per 90 Direct free kicks per 90 Direct free kicks on target, %  \
# 0               0.00                     0.00                            0.0
# 1               0.00                     0.00                            0.0
# 2               0.11                     0.06                            0.0
# 3               0.05                     0.00                            0.0
# 4               0.12                     0.06                            0.0
#
#   Corners per 90  Penalties taken  Penalty conversion, %
# 0           0.09                0                      0
# 1           0.00                0                      0
# 2           0.06                0                      0
# 3           0.00                0                      0
# 4           0.00                0                      0
#
# [5 rows x 115 columns]

# %%
# Get a summary of the data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Columns: 115 entries, Player to Penalty conversion, %
# dtypes: float64(87), int64(19), object(9)
# memory usage: 264.3+ KB
# None

# %%
# Display basic statistics for numerical columns
print(df.describe())
# Out:
#               Age   Market value  Matches played  Minutes played       Goals  \
# count  272.000000     294.000000      294.000000      294.000000  294.000000
# mean    24.077206    5782.312925        9.775510      691.340136    0.792517
# std      3.716612   41522.643521        4.729973      455.706877    1.440923
# min     17.000000       0.000000        1.000000        5.000000    0.000000
# 25%     21.000000       0.000000        6.000000      290.750000    0.000000
# 50%     24.000000       0.000000       11.000000      654.000000    0.000000
# 75%     27.000000       0.000000       14.000000     1039.500000    1.000000
# max     35.000000  500000.000000       17.000000     1657.000000   11.000000
#
#                xG     Assists          xA  Duels per 90  Duels won, %  ...  \
# count  294.000000  294.000000  294.000000    280.000000    280.000000  ...
# mean     0.792993    0.391156    0.547313     20.089357     47.410429  ...
# std      1.107322    0.696204    0.705024      5.258969      9.867032  ...
# min      0.000000    0.000000    0.000000      9.450000     14.290000  ...
# 25%      0.100000    0.000000    0.050000     16.505000     41.232500  ...
# 50%      0.380000    0.000000    0.295000     19.575000     47.225000  ...
# 75%      0.997500    1.000000    0.807500     23.095000     54.142500  ...
# max      7.450000    3.000000    5.350000     39.820000     72.220000  ...
#
#        Prevented goals per 90  Back passes received as GK per 90  \
# count                     0.0                         280.000000
# mean                      NaN                           0.460964
# std                       NaN                           0.529146
# min                       NaN                           0.000000
# 25%                       NaN                           0.000000
# 50%                       NaN                           0.290000
# 75%                       NaN                           0.680000
# max                       NaN                           2.440000
#
#        Exits per 90  Aerial duels per 90.1  Free kicks per 90  \
# count           0.0                    0.0         280.000000
# mean            NaN                    NaN           0.199464
# std             NaN                    NaN           0.476451
# min             NaN                    NaN           0.000000
# 25%             NaN                    NaN           0.000000
# 50%             NaN                    NaN           0.000000
# 75%             NaN                    NaN           0.132500
# max             NaN                    NaN           2.970000
#
#        Direct free kicks per 90  Direct free kicks on target, %  \
# count                280.000000                       280.00000
# mean                   0.035857                         4.84225
# std                    0.120605                        18.60391
# min                    0.000000                         0.00000
# 25%                    0.000000                         0.00000
# 50%                    0.000000                         0.00000
# 75%                    0.000000                         0.00000
# max                    1.250000                       100.00000
#
#        Corners per 90  Penalties taken  Penalty conversion, %
# count      280.000000       294.000000              294.00000
# mean         0.386429         0.044218                1.70068
# std          0.951571         0.342771               12.95169
# min          0.000000         0.000000                0.00000
# 25%          0.000000         0.000000                0.00000
# 50%          0.000000         0.000000                0.00000
# 75%          0.272500         0.000000                0.00000
# max          5.410000         4.000000              100.00000
#
# [8 rows x 106 columns]

# %%
# Identify all empty columns
empty_columns = [col for col in df.columns if df[col].isna().all()]

if empty_columns:
    print("Empty columns:", empty_columns)
else:
    print("No empty columns found.")
# Out:
# Empty columns: ['Conceded goals per 90', 'Shots against per 90', 'Prevented goals', 'Prevented goals per 90', 'Exits per 90', 'Aerial duels per 90.1']

# %%
# Since my idea is to create a single db for every role, I need to keep the columns relative to GKs. The only real empty column to drop is 'Aerial duels per 90.1', which was likely an hidden copy of 'Aerial duels per 90'
df.drop(columns=['Aerial duels per 90.1'], inplace=True)

# %%
# Create a DataFrame of column names and their types
column_types = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values
})

# Temporarily allow Pandas to display all rows
with pd.option_context('display.max_rows', None):
    display(column_types)
# Out:
#                                    Column Data Type
# 0                                  Player    object
# 1                                    Team    object
# 2          Team within selected timeframe    object
# 3                                Position    object
# 4                                     Age   float64
# 5                            Market value     int64
# 6                        Contract expires    object
# 7                          Matches played     int64
# 8                          Minutes played     int64
# 9                                   Goals     int64
# 10                                     xG   float64
# 11                                Assists     int64
# 12                                     xA   float64
# 13                           Duels per 90   float64
# 14                           Duels won, %   float64
# 15                          Birth country    object
# 16                       Passport country    object
# 17                                   Foot    object
# 18                                 Height     int64
# 19                                 Weight     int64
# 20                                On loan    object
# 21    Successful defensive actions per 90   float64
# 22                 Defensive duels per 90   float64
# 23                 Defensive duels won, %   float64
# 24                    Aerial duels per 90   float64
# 25                    Aerial duels won, %   float64
# 26                 Sliding tackles per 90   float64
# 27                   PAdj Sliding tackles   float64
# 28                   Shots blocked per 90   float64
# 29                   Interceptions per 90   float64
# 30                     PAdj Interceptions   float64
# 31                           Fouls per 90   float64
# 32                           Yellow cards     int64
# 33                    Yellow cards per 90   float64
# 34                              Red cards     int64
# 35                       Red cards per 90   float64
# 36    Successful attacking actions per 90   float64
# 37                           Goals per 90   float64
# 38                      Non-penalty goals     int64
# 39               Non-penalty goals per 90   float64
# 40                              xG per 90   float64
# 41                             Head goals     int64
# 42                      Head goals per 90   float64
# 43                                  Shots     int64
# 44                           Shots per 90   float64
# 45                     Shots on target, %   float64
# 46                     Goal conversion, %   float64
# 47                         Assists per 90   float64
# 48                         Crosses per 90   float64
# 49                    Accurate crosses, %   float64
# 50         Crosses from left flank per 90   float64
# 51    Accurate crosses from left flank, %   float64
# 52        Crosses from right flank per 90   float64
# 53   Accurate crosses from right flank, %   float64
# 54           Crosses to goalie box per 90   float64
# 55                        Dribbles per 90   float64
# 56                 Successful dribbles, %   float64
# 57                 Offensive duels per 90   float64
# 58                 Offensive duels won, %   float64
# 59                  Touches in box per 90   float64
# 60                Progressive runs per 90   float64
# 61                   Accelerations per 90   float64
# 62                 Received passes per 90   float64
# 63            Received long passes per 90   float64
# 64                  Fouls suffered per 90   float64
# 65                          Passes per 90   float64
# 66                     Accurate passes, %   float64
# 67                  Forward passes per 90   float64
# 68             Accurate forward passes, %   float64
# 69                     Back passes per 90   float64
# 70                Accurate back passes, %   float64
# 71                  Lateral passes per 90   float64
# 72             Accurate lateral passes, %   float64
# 73           Short / medium passes per 90   float64
# 74      Accurate short / medium passes, %   float64
# 75                     Long passes per 90   float64
# 76                Accurate long passes, %   float64
# 77                 Average pass length, m   float64
# 78            Average long pass length, m   float64
# 79                              xA per 90   float64
# 80                    Shot assists per 90   float64
# 81                  Second assists per 90   float64
# 82                   Third assists per 90   float64
# 83                    Smart passes per 90   float64
# 84               Accurate smart passes, %   float64
# 85                      Key passes per 90   float64
# 86           Passes to final third per 90   float64
# 87      Accurate passes to final third, %   float64
# 88          Passes to penalty area per 90   float64
# 89     Accurate passes to penalty area, %   float64
# 90                  Through passes per 90   float64
# 91             Accurate through passes, %   float64
# 92                Deep completions per 90   float64
# 93          Deep completed crosses per 90   float64
# 94              Progressive passes per 90   float64
# 95         Accurate progressive passes, %   float64
# 96                         Conceded goals     int64
# 97                  Conceded goals per 90   float64
# 98                          Shots against     int64
# 99                   Shots against per 90   float64
# 100                          Clean sheets     int64
# 101                          Save rate, %     int64
# 102                            xG against     int64
# 103                     xG against per 90   float64
# 104                       Prevented goals   float64
# 105                Prevented goals per 90   float64
# 106     Back passes received as GK per 90   float64
# 107                          Exits per 90   float64
# 108                     Free kicks per 90   float64
# 109              Direct free kicks per 90   float64
# 110        Direct free kicks on target, %   float64
# 111                        Corners per 90   float64
# 112                       Penalties taken     int64
# 113                 Penalty conversion, %     int64

# %%
# Converting objetc types more appropriate types depending on the attributes

to_string = ['Player', 'Team', 'Team within selected timeframe', 'Birth country', 'Foot'] 

for column in to_string:
    df[column] = df[column].astype('string')

# Convert 'Position' and 'Passport country' columns to lists (format usable in PostgreSQL)
df['Position'] = df['Position'].str.split(', ')
df['Position'] = df['Position'].apply(lambda x: '{' + ','.join(x) + '}' if isinstance(x, list) else '{}')
df['Passport country'] = df['Passport country'].str.split(', ')
df['Passport country'] = df['Passport country'].apply(lambda x: '{' + ','.join(x) + '}' if isinstance(x, list) else '{}')

# Convert Position and Passport country from object to a list of strings
#to_string_list = ['Position', 'Passport country']
#for column in to_string_list:
#    df[column] = df[column].str.split(', ')

# Convert Contract expires to a date
df['Contract expires'] = pd.to_datetime(df['Contract expires'], errors='coerce')
# Ensure 'Contract expires' contains only the date (year-month-day)
df['Contract expires'] = df['Contract expires'].dt.date

# Replace 'yes' with True and 'no' with False
df['On loan'] = df['On loan'].replace({'yes': True, 'no': False}).fillna(False).astype('bool')

# There is no reason to use so much memory to store these int and float attributes, they're all numbers with a limited range: int16 is safe for all these attributes except Market value
# Convert all int64 columns to int16, except for 'Market value' which should be int32
df = df.apply(lambda x: x.astype('int16') if x.dtype == 'int64' and x.name != 'Market value' else
                  (x.astype('int32') if x.name == 'Market value' else x))

# Convert all float64 columns to float16: same reason, float16 are already large enough to comfortably hold any possible value of these attributes (mostly percentages and per 90 values)
df = df.apply(lambda x: x.astype('float16') if x.dtype == 'float64' else x)

# %%
# Check type changes
# Create a DataFrame of column names and their types
column_types = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values
})

# Temporarily allow Pandas to display all rows
with pd.option_context('display.max_rows', None):
    display(column_types)
# Out:
#                                    Column       Data Type
# 0                                  Player  string[python]
# 1                                    Team  string[python]
# 2          Team within selected timeframe  string[python]
# 3                                Position          object
# 4                                     Age         float16
# 5                            Market value           int32
# 6                        Contract expires          object
# 7                          Matches played           int16
# 8                          Minutes played           int16
# 9                                   Goals           int16
# 10                                     xG         float16
# 11                                Assists           int16
# 12                                     xA         float16
# 13                           Duels per 90         float16
# 14                           Duels won, %         float16
# 15                          Birth country  string[python]
# 16                       Passport country          object
# 17                                   Foot  string[python]
# 18                                 Height           int16
# 19                                 Weight           int16
# 20                                On loan            bool
# 21    Successful defensive actions per 90         float16
# 22                 Defensive duels per 90         float16
# 23                 Defensive duels won, %         float16
# 24                    Aerial duels per 90         float16
# 25                    Aerial duels won, %         float16
# 26                 Sliding tackles per 90         float16
# 27                   PAdj Sliding tackles         float16
# 28                   Shots blocked per 90         float16
# 29                   Interceptions per 90         float16
# 30                     PAdj Interceptions         float16
# 31                           Fouls per 90         float16
# 32                           Yellow cards           int16
# 33                    Yellow cards per 90         float16
# 34                              Red cards           int16
# 35                       Red cards per 90         float16
# 36    Successful attacking actions per 90         float16
# 37                           Goals per 90         float16
# 38                      Non-penalty goals           int16
# 39               Non-penalty goals per 90         float16
# 40                              xG per 90         float16
# 41                             Head goals           int16
# 42                      Head goals per 90         float16
# 43                                  Shots           int16
# 44                           Shots per 90         float16
# 45                     Shots on target, %         float16
# 46                     Goal conversion, %         float16
# 47                         Assists per 90         float16
# 48                         Crosses per 90         float16
# 49                    Accurate crosses, %         float16
# 50         Crosses from left flank per 90         float16
# 51    Accurate crosses from left flank, %         float16
# 52        Crosses from right flank per 90         float16
# 53   Accurate crosses from right flank, %         float16
# 54           Crosses to goalie box per 90         float16
# 55                        Dribbles per 90         float16
# 56                 Successful dribbles, %         float16
# 57                 Offensive duels per 90         float16
# 58                 Offensive duels won, %         float16
# 59                  Touches in box per 90         float16
# 60                Progressive runs per 90         float16
# 61                   Accelerations per 90         float16
# 62                 Received passes per 90         float16
# 63            Received long passes per 90         float16
# 64                  Fouls suffered per 90         float16
# 65                          Passes per 90         float16
# 66                     Accurate passes, %         float16
# 67                  Forward passes per 90         float16
# 68             Accurate forward passes, %         float16
# 69                     Back passes per 90         float16
# 70                Accurate back passes, %         float16
# 71                  Lateral passes per 90         float16
# 72             Accurate lateral passes, %         float16
# 73           Short / medium passes per 90         float16
# 74      Accurate short / medium passes, %         float16
# 75                     Long passes per 90         float16
# 76                Accurate long passes, %         float16
# 77                 Average pass length, m         float16
# 78            Average long pass length, m         float16
# 79                              xA per 90         float16
# 80                    Shot assists per 90         float16
# 81                  Second assists per 90         float16
# 82                   Third assists per 90         float16
# 83                    Smart passes per 90         float16
# 84               Accurate smart passes, %         float16
# 85                      Key passes per 90         float16
# 86           Passes to final third per 90         float16
# 87      Accurate passes to final third, %         float16
# 88          Passes to penalty area per 90         float16
# 89     Accurate passes to penalty area, %         float16
# 90                  Through passes per 90         float16
# 91             Accurate through passes, %         float16
# 92                Deep completions per 90         float16
# 93          Deep completed crosses per 90         float16
# 94              Progressive passes per 90         float16
# 95         Accurate progressive passes, %         float16
# 96                         Conceded goals           int16
# 97                  Conceded goals per 90         float16
# 98                          Shots against           int16
# 99                   Shots against per 90         float16
# 100                          Clean sheets           int16
# 101                          Save rate, %           int16
# 102                            xG against           int16
# 103                     xG against per 90         float16
# 104                       Prevented goals         float16
# 105                Prevented goals per 90         float16
# 106     Back passes received as GK per 90         float16
# 107                          Exits per 90         float16
# 108                 Aerial duels per 90.1         float16
# 109                     Free kicks per 90         float16
# 110              Direct free kicks per 90         float16
# 111        Direct free kicks on target, %         float16
# 112                        Corners per 90         float16
# 113                       Penalties taken           int16
# 114                 Penalty conversion, %           int16

# %%
# Ensuring the conversion has worked
print(type(df['Position'][0]))
# Out:
# <class 'str'>

# %%
print(type(df['Contract expires'][1]))
# Out:
# <class 'datetime.date'>

# %%
# Checking the first rows of the dataframe after the conversions
display(df.head())
# Out:
#           Player                Team Team within selected timeframe  \
# 0  T. Owen-Evans     Chippenham Town                Chippenham Town
# 1       D. Sesay  Eastbourne Borough             Eastbourne Borough
# 2       T. Clark         Farnborough                    Farnborough
# 3      B. Roscoe        Radcliffe FC                   Radcliffe FC
# 4     G. Horbury             Chorley                        Chorley
#
#          Position   Age  Market value Contract expires  Matches played  \
# 0      {RW,LW,CF}  27.0             0              NaT              17
# 1     {RB,LWB,LB}  26.0             0       2025-06-30              17
# 2  {RB,LDMF,RDMF}  19.0             0              NaT              17
# 3        {RCB,RB}  27.0             0              NaT              17
# 4  {RW,RCMF,LCMF}  20.0             0              NaT              17
#
#    Minutes played  Goals  ...  Prevented goals per 90  \
# 0             951      4  ...                     NaN
# 1            1512      0  ...                     NaN
# 2            1580      2  ...                     NaN
# 3            1657      5  ...                     NaN
# 4            1522      1  ...                     NaN
#
#    Back passes received as GK per 90  Exits per 90  Aerial duels per 90.1  \
# 0                           0.379883           NaN                    NaN
# 1                           0.600098           NaN                    NaN
# 2                           1.139648           NaN                    NaN
# 3                           1.849609           NaN                    NaN
# 4                           0.059998           NaN                    NaN
#
#    Free kicks per 90 Direct free kicks per 90 Direct free kicks on target, %  \
# 0           0.000000                 0.000000                            0.0
# 1           0.000000                 0.000000                            0.0
# 2           0.109985                 0.059998                            0.0
# 3           0.049988                 0.000000                            0.0
# 4           0.119995                 0.059998                            0.0
#
#   Corners per 90  Penalties taken  Penalty conversion, %
# 0       0.090027                0                      0
# 1       0.000000                0                      0
# 2       0.059998                0                      0
# 3       0.000000                0                      0
# 4       0.000000                0                      0
#
# [5 rows x 115 columns]

# %%
# Save the DataFrame to a new Excel file called 'players-db.xlsx'
df.to_excel('players-db.xlsx', index=False)
